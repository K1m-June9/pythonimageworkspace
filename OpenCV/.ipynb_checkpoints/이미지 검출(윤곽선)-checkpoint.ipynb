# %% [markdown]
# # 이미지 검출(윤곽선)

# %% [markdown]
# ## 윤곽선(Contour): 경계선을 연결한 선

# %%
import cv2
img = cv2.imread('card.png')
target_img = img.copy() #사본 이미지

gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, otsu = cv2.threshold(gray, -1, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

contours, hierarchy = cv2.findContours(otsu, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE) #윤곽선 검출
# 윤곽선 정보, 구조
# 이미지, 윤곽선을 찾는 모드(mode), 윤곽선을 찾을 때 사용하는 근사치 방법(method): CHAIN_APPROX_NONE(모든 좌표의 정보),CHAIN_APPROX_SIMPLE(꼭짓점 좌표의 정보)
COLOR = (0,200,2)#BGR
cv2.drawContours(target_img, contours, -1,COLOR,2)
# 대상 이미지, 윤곽선 정보, 인덱스(-1이면 전체), 색깔, 윤곽선 두께)
#윤곽선 그리기

cv2.imshow('img',img)
cv2.imshow('otsu',otsu)
cv2.imshow('contour',target_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# 2024-02-11 02:40:11.761 python[7563:3554107] Warning: Window move completed without beginning
# 2024-02-11 02:40:15.175 python[7563:3554107] Warning: Window move completed without beginning
# -1

# %% [markdown]
# ### 윤곽선 찾기 모드
# 1. cv2.RETR_EXTERNAL: 가장 외곽의 윤곽선만 찾음
# 2. cv2.RETR_LIST: 모든 윤곽선을 찾음(계층 정보 없음)
# 3. cv2.RETR_TREE:모든 윤곽선을 찾음(계층 정보를 트리구조로 생성)

# %%
import cv2
img = cv2.imread('card.png')
target_img = img.copy() #사본 이미지

gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, otsu = cv2.threshold(gray, -1, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

#contours, hierarchy = cv2.findContours(otsu, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE) 
#contours, hierarchy = cv2.findContours(otsu, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 
# contours, hierarchy = cv2.findContours(otsu, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE) 


COLOR = (0,200,2)#BGR
cv2.drawContours(target_img, contours, -1,COLOR,2)


cv2.imshow('contour',target_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# [[[ 1 -1 -1 -1]
#   [ 2  0 -1 -1]
#   [10  1  3 -1]
#   [ 5 -1  4  2]
#   [-1 -1 -1  3]
#   [ 6  3 -1  2]
#   [ 7  5 -1  2]
#   [ 8  6 -1  2]
#   [-1  7  9  2]
#   [-1 -1 -1  8]
#   [18  2 11 -1]
#   [13 -1 12 10]
#   [-1 -1 -1 11]
#   [14 11 -1 10]
#   [15 13 -1 10]
#   [16 14 -1 10]
#   [-1 15 17 10]
#   [-1 -1 -1 16]
#   [26 10 19 -1]
#   [21 -1 20 18]
#   [-1 -1 -1 19]
#   [22 19 -1 18]
#   [23 21 -1 18]
#   [24 22 -1 18]
#   [-1 23 25 18]
#   [-1 -1 -1 24]
#   [34 18 27 -1]
#   [29 -1 28 26]
#   [-1 -1 -1 27]
#   [30 27 -1 26]
#   [31 29 -1 26]
#   [32 30 -1 26]
#   [-1 31 33 26]
#   [-1 -1 -1 32]
#   [35 26 -1 -1]
#   [-1 34 -1 -1]]]
# -1

# %% [markdown]
# ## 경계 사각형
# 윤곽선의 경계면을 둘러싸는 사각형
# > boundingRect()

# %%
import cv2
img = cv2.imread('card.png')
target_img = img.copy() #사본 이미지

gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, otsu = cv2.threshold(gray, -1, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

contours, hierarchy = cv2.findContours(otsu, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE) 


COLOR = (0,200,2)#BGR
#cv2.drawContours(target_img, contours, -1,COLOR,2)

for cnt in contours:
    x,y, width,height = cv2.boundingRect(cnt)
    cv2.rectangle(target_img, (x,y),(x+width,y+height),COLOR,2) #사각형 그림

cv2.imshow('contour',target_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %% [markdown]
# ## 면적
# > contourArea()

# %%
import cv2
img = cv2.imread('card.png')
target_img = img.copy() #사본 이미지

gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, otsu = cv2.threshold(gray, -1, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

contours, hierarchy = cv2.findContours(otsu, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE) 


COLOR = (0,200,2)#BGR
#cv2.drawContours(target_img, contours, -1,COLOR,2)

for cnt in contours:
    if cv2.contourArea(cnt) > 25000:
        x,y, width,height = cv2.boundingRect(cnt)
        cv2.rectangle(target_img, (x,y),(x+width,y+height),COLOR,2) #사각형 그림

cv2.imshow('contour',target_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)

# %% [markdown]
# ## 미니 프로젝트: 개별 카드 추출해서 파일 저장

# %%
import cv2
img = cv2.imread('card.png')
target_img = img.copy() #사본 이미지

gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, otsu = cv2.threshold(gray, -1, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

contours, hierarchy = cv2.findContours(otsu, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE) 


COLOR = (0,200,2)#BGR
#cv2.drawContours(target_img, contours, -1,COLOR,2)
idx = 1
for cnt in contours:
    if cv2.contourArea(cnt) > 25000:
        x,y, width,height = cv2.boundingRect(cnt)
        cv2.rectangle(target_img, (x,y),(x+width,y+height),COLOR,2) #사각형 그림

        crop = img[y:y+height, x:x+width]
        cv2.imshow(f'crop_{idx}',crop)
        cv2.imwrite(f'card_crop_{idx}.png',crop) #저장
        idx+=1
        
cv2.imshow('contour',target_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# 2024-02-12 02:30:57.290 python[9031:3607178] Warning: Window move completed without beginning
# 2024-02-12 02:30:59.639 python[9031:3607178] Warning: Window move completed without beginning
# 2024-02-12 02:31:01.042 python[9031:3607178] Warning: Window move completed without beginning
# 2024-02-12 02:31:02.629 python[9031:3607178] Warning: Window move completed without beginning
# -1
