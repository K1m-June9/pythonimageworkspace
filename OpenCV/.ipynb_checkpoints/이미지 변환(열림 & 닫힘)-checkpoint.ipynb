# %% [markdown]
# # 이미지 변환(열림 & 닫힘)

# %% [markdown]
# ## 열림(Opening): 침식 후 팽창 깎아서 노이즈 제거 후 살 찌움
# dilate(erode(image))

# %%
import cv2
import numpy as np

kernel = np.ones((3,3),dtype = np.uint8)
img = cv2.imread('reload.png', cv2.IMREAD_GRAYSCALE)

erode = cv2.erode(img, kernel, iterations=5)
dilate = cv2.dilate(erode, kernel, iterations=5)

cv2.imshow('img',img)
cv2.imshow('erode',erode)
cv2.imshow('dilate',dilate)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# 2024-02-11 02:08:39.712 python[6760:3538558] Warning: Window move completed without beginning
# 2024-02-11 02:08:42.277 python[6760:3538558] Warning: Window move completed without beginning
# -1

# %% [markdown]
# ## 닫힘(Closing): 팽창 후 침식, 구멍을 메운 후 다시 깎음
# erode(dilate(image))

# %%
import cv2
import numpy as np

kernel = np.ones((3,3),dtype = np.uint8)
img = cv2.imread('dilate.png', cv2.IMREAD_GRAYSCALE)

dilate = cv2.dilate(img, kernel, iterations=5)
erode = cv2.erode(dilate, kernel, iterations=5)

cv2.imshow('img',img)
cv2.imshow('erode',erode)
cv2.imshow('dilate',dilate)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# 2024-02-11 02:11:38.132 python[6760:3538558] Warning: Window move completed without beginning
# 2024-02-11 02:11:40.451 python[6760:3538558] Warning: Window move completed without beginning
# -1
