# %% [markdown]
# # OpenCV(Computer Vision)
# 다양한 영상(이미지)/동영상 처리에 사용되는 오픈소스 라이브러리

# %%
import cv2
cv2.__version__
# Out:
# '4.9.0'

# %% [markdown]
# # 이미지 출력

# %%
import cv2
img = cv2.imread('img.jpg') #해당 경로의 파일 일어오기
cv2.imshow('img',img) #img라는 이름의 창에 img를 표시
key = cv2. waitKey(0) #지정된 시간동안 사용자 . 키입력 대기
print(key) #Key값은 ASCII
cv2.destroyAllWindows() #모든 창 닫기
# Out:
# 66

# %% [markdown]
# ## 읽기옵션
# 1. cv2.IMREAD_COLOR: 컬러이미지, 투명 영역은 무시(기본값)
# 2. cv2.IMREAD_GRAYSCALE: 흑백 이미지
# 3. cv2.IMREAD_UNCHANGED : 투명 영역까지 포함

# %%
import cv2
img_color = cv2.imread('img.jpg',cv2.IMREAD_COLOR)
img_gray = cv2.imread('img.jpg',cv2.IMREAD_GRAYSCALE)
cv2.imshow('img_color',img_color)
cv2.imshow('img_gray',img_gray)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 2024-06-02 13:58:27.853 python[39709:1276719] Warning: Window move completed without beginning

# %% [markdown]
# ## Shape
# 이미지의 height, height, channel 정보

# %%
import cv2
img = cv2.imread('img.jpg')
img.shape #가로, 세로, channel[3 -> RGB 세 개의 값을 가짐(나중가면 투명도까지 4)]
# Out:
# (391, 640, 3)
